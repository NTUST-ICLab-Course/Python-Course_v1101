# %% [markdown]
# # File Object in Python and Example of N-gram Language Model

# %% [markdown]
# content:
# 1. File object with context manager
# 2. $N$-gram: 如何利用 dictionary計算 「詞」出現的次數
# 3. 拼音模組 pypinyin：找同音字

# %% [markdown]
# ## *Corey Schafer Python Tutorial*
# ## File Objects - Reading and Writing to Files
# https://www.youtube.com/watch?v=Uh2ebFW8OYM&t=542s

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Uh2ebFW8OYM" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Uh2ebFW8OYM" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# %pwd
# Out:
# 'D:\\Google雲端硬碟\\GettingStartedWithPythonAndRaspberryPi-book_release\\Chapter03'

# %% [markdown]
# ## with: context manager
#
# 最大的優點是，原本要讀、寫檔案，要先：open(), read()/write(), 然後 close() 的三行指令，而且要處理，當開關檔的過程中，要是有錯誤的處理。有點麻煩。
#
# 使用 with open("filename", "r") as f:
#
# 的優點是，關檔的動作，這個 context manager 會幫忙處理掉。
#
# 而且，另外在從一個檔案 (source) 讀出內容，然後寫到另外一個檔案 (destination) 的過程中，也可以使用兩個 (nested) with 的指令。

# %%
import os
os.listdir()
# Out:
# ['.ipynb',
#  '.ipynb_checkpoints',
#  '500句子病歷.txt',
#  'Ch03Drill.ipynb',
#  'Ch03_readme.txt',
#  'changeToCourseDirectory.ipynb',
#  'Chapter_03_by_Chung_py3_2019.ipynb',
#  'Chapter_03_complimentary_Corey_Shafer.ipynb',
#  'Chapter_03_Read_me.ipynb',
#  'desktop.ini',
#  'Dictionary_Operations.py',
#  'Dictionary_Set.py',
#  'Dictionary_Simple.py',
#  'File Object in Python.ipynb',
#  'File_Objects.py',
#  'hw8_330.py',
#  'Lists_Append.py',
#  'Lists_ConditionalGenerator.py',
#  'Lists_ModificationGenerator.py',
#  'Lists_Operations.py',
#  'Lists_Simple.py',
#  'n-gram.ipynb',
#  'newChapter3byChung.py',
#  'news.txt',
#  'news1.txt',
#  'os_path.py',
#  'SampleFile.txt',
#  'SampleFile3.txt',
#  'Sets_Create.py',
#  'Sets_Frozen.py',
#  'Sets_Operations.py',
#  'test.htm',
#  'test.txt',
#  'testw.txt',
#  'Tuples.py',
#  '§03_01_List.ipynb',
#  '§03_02_Dictionary.ipynb',
#  '§03_03_Set_FrozenSet_Tuple.ipynb',
#  '§03_04_osPath.ipynb',
#  '§03_05_ReadingAndWritingToFiles.ipynb',
#  '§03_Complete_2020_Fall.ipynb',
#  '病歷500句子.txt']

# %%
'''
我們來讀裏面的 test.txt 檔案

一般存取檔案，要先 open()，作讀/寫動作，然後結束前要 close()。
通常還拌隨一些開關沒成功時的處理，
以及要特別記得關檔，
有點麻煩。
'''
f = open("test.txt", "r")
f_contents = f.read()
print(f_contents)
f.close()
# Out:
# 1) This is a test file
# 2) With multiple lines of data...
# 3) Third line
# 4) Fourth line
# 5) Fifth line
# 6) Sixth line
# 7) Seventh line
# 8) Eighth line
# 9) Ninth line
# 10) Tenth line

# %%
'''
context-manager 的意思是，限定在某特定情境 (context) 之下，
執行相關的程序。
'''
with open("test.txt") as f:
    f_contents = f.read()
    print(f_contents)
# Out:
# 1) This is a test file
# 2) With multiple lines of data...
# 3) Third line
# 4) Fourth line
# 5) Fifth line
# 6) Sixth line
# 7) Seventh line
# 8) Eighth line
# 9) Ninth line
# 10) Tenth line

# %%
with open("testw.txt", "w") as f:
    f.write("It\'s complicated!")

# %%
# %more testw.txt

# %%
'''
檔案讀寫頭的位置：f.tell()
搬動到指定位置：f.seek()

英文的狀況很單純，17 個字符，共用掉 17 bytes
'''
with open("testw.txt", "w") as f:
    print(len("It\'s complicated!")) # 長度為 17
    f.write("It\'s complicated!")
    print(f.tell()) #位置由 0 開始標記，此時正在句子後的那個空格上
    f.seek(8) # 硬將讀寫頭搬回由 0 開始的標號 8
    f.write("XX")
    
with open("testw.txt", "r") as f:
    #f.seek(0)
    print(f.readline())
    print("01234567890123456")
# Out:
# 17
# 17
# It's comXXicated!
# 01234567890123456

# %% [markdown]
# ##  準備寫一個計算 n-gram 的 python 程式
# 文本 (text) 為 病歷500句子.txt (UTF-8 編碼方式)

# %%
import os
path_name = os.getcwd()
path_name
# Out:
# 'D:\\Google雲端硬碟\\GettingStartedWithPythonAndRaspberryPi-book_release\\Chapter03'

# %%
print(path_name)
# Out:
# D:\Google雲端硬碟\GettingStartedWithPythonAndRaspberryPi-book_release\Chapter03

# %%
# %ls
# os.listdir()
# Out:
#  磁碟區 D 中的磁碟是 新增磁碟區
#  磁碟區序號:  E422-9B08
#
#  D:\Google雲端硬碟\GettingStartedWithPythonAndRaspberryPi-book_release\Chapter03 的目錄
#
# 2020/10/06  下午 01:57    <DIR>          .
# 2020/10/06  下午 01:57    <DIR>          ..
# 2019/03/11  下午 12:19           247,888 .ipynb
# 2020/10/06  上午 08:01    <DIR>          .ipynb_checkpoints
# 2020/09/28  下午 02:39            53,161 §03_01_List.ipynb
# 2020/09/28  下午 04:11            27,580 §03_02_Dictionary.ipynb
# 2020/09/28  下午 04:40            60,490 §03_03_Set_FrozenSet_Tuple.ipynb
# 2020/09/28  下午 05:01            16,751 §03_04_osPath.ipynb
# 2020/09/28  下午 05:49            60,414 §03_05_ReadingAndWritingToFiles.ipynb
# 2020/09/22  下午 08:34           195,478 §03_Complete_2020_Fall.ipynb
# 2020/10/05  上午 06:24            30,122 500句子病歷.txt
# 2019/09/30  上午 10:15               460 Ch03_readme.txt
# 2020/09/27  上午 08:23            82,198 Ch03Drill.ipynb
# 2020/09/27  下午 08:44            93,397 changeToCourseDirectory.ipynb
# 2020/09/22  下午 08:04           195,475 Chapter_03_by_Chung_py3_2019.ipynb
# 2020/09/20  下午 04:16             2,644 Chapter_03_complimentary_Corey_Shafer.ipynb
# 2020/10/05  下午 07:23             1,124 Chapter_03_Read_me.ipynb
# 2018/03/13  上午 03:09               796 Dictionary_Operations.py
# 2018/03/13  上午 03:09               107 Dictionary_Set.py
# 2018/03/13  上午 03:09               107 Dictionary_Simple.py
# 2020/10/06  下午 01:57            19,828 File Object in Python.ipynb
# 2018/03/13  上午 03:09               544 File_Objects.py
# 2019/06/10  下午 12:21             4,759 hw8_330.py
# 2018/03/13  上午 03:09               280 Lists_Append.py
# 2018/03/13  上午 03:09               465 Lists_ConditionalGenerator.py
# 2018/03/13  上午 03:09               642 Lists_ModificationGenerator.py
# 2018/03/13  上午 03:09               592 Lists_Operations.py
# 2018/03/13  上午 03:09                84 Lists_Simple.py
# 2018/03/31  下午 03:53            10,597 newChapter3byChung.py
# 2020/09/27  下午 02:11             3,491 news.txt
# 2020/09/27  下午 02:16             3,491 news1.txt
# 2020/10/06  上午 11:59           864,956 n-gram.ipynb
# 2018/03/13  上午 03:09             1,102 os_path.py
# 2020/09/28  下午 05:33                37 SampleFile.txt
# 2020/09/28  下午 05:46               153 SampleFile3.txt
# 2018/03/13  上午 03:09               224 Sets_Create.py
# 2018/03/13  上午 03:09               158 Sets_Frozen.py
# 2018/03/13  上午 03:09               512 Sets_Operations.py
# 2020/09/27  下午 02:48            86,140 test.htm
# 2020/09/27  下午 02:57               182 test.txt
# 2020/10/06  下午 01:49                17 testw.txt
# 2018/03/13  上午 03:09               297 Tuples.py
# 2020/09/27  下午 09:12            30,122 病歷500句子.txt
#               40 個檔案       2,096,865 位元組
#                3 個目錄  896,187,383,808 位元組可用

# %%
os.listdir()
# Out:
# ['.ipynb',
#  '.ipynb_checkpoints',
#  '500句子病歷.txt',
#  'Ch03Drill.ipynb',
#  'Ch03_readme.txt',
#  'changeToCourseDirectory.ipynb',
#  'Chapter_03_by_Chung_py3_2019.ipynb',
#  'Chapter_03_complimentary_Corey_Shafer.ipynb',
#  'Chapter_03_Read_me.ipynb',
#  'desktop.ini',
#  'Dictionary_Operations.py',
#  'Dictionary_Set.py',
#  'Dictionary_Simple.py',
#  'File Object in Python.ipynb',
#  'File_Objects.py',
#  'hw8_330.py',
#  'Lists_Append.py',
#  'Lists_ConditionalGenerator.py',
#  'Lists_ModificationGenerator.py',
#  'Lists_Operations.py',
#  'Lists_Simple.py',
#  'n-gram.ipynb',
#  'newChapter3byChung.py',
#  'news.txt',
#  'news1.txt',
#  'os_path.py',
#  'SampleFile.txt',
#  'SampleFile3.txt',
#  'Sets_Create.py',
#  'Sets_Frozen.py',
#  'Sets_Operations.py',
#  'test.htm',
#  'test.txt',
#  'testw.txt',
#  'Tuples.py',
#  '§03_01_List.ipynb',
#  '§03_02_Dictionary.ipynb',
#  '§03_03_Set_FrozenSet_Tuple.ipynb',
#  '§03_04_osPath.ipynb',
#  '§03_05_ReadingAndWritingToFiles.ipynb',
#  '§03_Complete_2020_Fall.ipynb',
#  '病歷500句子.txt']

# %%
with open("500句子病歷.txt", "r") as f:
    f_content = f.read()
    print(f_content)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-a389667f1576> in <module>
#       1 with open("500句子病歷.txt", "r") as f:
# ----> 2     f_content = f.read()
#       3     print(f_content)
#
# UnicodeDecodeError: 'cp950' codec can't decode byte 0x9b in position 5: illegal multibyte sequence

# %% [markdown]
# ## 解決 Python 中 UnicodeDecodeError: 'cp950' codec can't decode
# https://oxygentw.net/blog/computer/python-file-utf8-encoding/

# %%
with open("病歷500句子.txt", "r", encoding="utf-8") as f:
    f_content = f.read()
    print(f_content)
# Out:
# == 衛福部台北醫院護理交班系統摘錄 500句子 ==
# 他沒什麼過敏史。
# 術後發現說他的右腹有開始有突出的狀況。
# 到門診去看，醫師就建議他入院。
# 現在尿都可以自解。
# 六月三十有發燒的狀況，那用冰枕之後就退了。
# 今年四月去健檢發現膽囊有息肉。
# 診斷是膽囊息肉。
# 隔天的話有發燒到三十八度六。
# 他說他沒有吃東西就想吐，後來就是有改善，就是有吃點米湯。
# 後來斷斷續續還是有發燒，那現在就是只有吃藥。
# 他一星期前開始感覺到左腰痛。
# 幫他做過碎石，但是沒有改善，石頭還在。
# 要做輸尿管鏡夾石頭。
# 開完刀回來那時候病人就平躺到十點。
# 病人之前就有高血壓，痔瘡有開過刀，肝膿瘍做過引流，雙眼白內障開過刀。
# 早上他有先去急診，看了可是沒有改善，所以等於說二十四小時又返回急診。
# 後來就幫他會診那個直腸外科的高彬勝醫師。
# 有幫他直接插了鼻胃管，然後做減壓。
# 膽固醇也有比較高，兩百四十二。
# 這個病人開完刀之後就轉到加護病房。
# 診斷是上頷骨骨折還有鼻骨骨折。
# 過去病史有異位性皮膚炎，還有右側氣胸。
# 他騎機車跟貨車相撞，然後鼻部那邊有擦傷，右膝、右外踝還有背部都有擦傷。
# 病人主述說有頭暈、嘔吐然後還有流鼻血的狀況。
# 有再幫他做眼窩的電腦斷層，然後就發現他右眼窩那邊有骨折。
# 抽血的話就是白血球是一萬六千三。
# 這邊重要提醒就是說他有骨折，上頷骨骨折，還有右眼窩那邊有骨折。
# 右臉盡量不要去壓到這樣子，睡覺或是平常就是要注意。
# 因為病人之後還要會整外，所以之後會請整外的張淳皓醫師來看他。
# 到時候要請家屬一定要在，醫師要跟他們解釋。
# 他右膝因為擦傷比較嚴重皮膚都沒有了，就是等於幫他貼人工皮。
# 他覺得說他的那個臉會稍微麻麻的，可是後來就改善。
# 醫師會來跟家屬討論說後續是不是要先開刀還是病人會先回家。
# 病人他暫時不開刀，之後在門診追蹤。
# 這次因為他後頸部的腫瘤已經大概十年。
# 醫師看過之後是建議說他還是要把他切除。
# 他對阿斯匹靈會過敏，海鮮也會過敏，伙食的話就是自備。
# 過去病史有高血壓、糖尿病、脊椎開過刀、子宮做全切除、胃出血。
# 這次住院因為他一個月前曾跌倒，導致他下背痛然後左下肢會痠麻痛。
# 病人的血糖三百零八，不過他表示說因為他剛吃了東西，所以就是沒有做處理。
# 他頭先使用束腹帶，後來才做背架。
# 有幫他會診，會他那個腸胃科。
# 因為他下肢無力就有幫他會復健科，復健科就說要幫他做一些下肢平衡的訓練。
# 那時候病人就不舒服，說他胸悶，就是會胸痛。
# 他有肋膜積水，所以說可能會做胸超。
# 因為這個病人後來喘，就是有轉加護病房。
# 現在病人可以由嘴巴吃，就是預防嗆到就可以了。
# 他左肩那邊就是有脫臼，所以有叫他用三角巾。
# 他四肢還有右肩都有一堆擦傷，那時候他來的時候有給他戴頸圈。
# 上禮拜車禍的時候是左肩有脫臼的狀況。
# 因為他有出血所以就是醫師有告病危。
# 他們擔心會有一些照顧的問題，所以有幫他會社工。
# 病人有時候會比較躁動所以他晚上會有鎮靜劑給他吃。
# 家屬有特別講說病人的左右臉好像不對稱。
# 可能就是因為一邊腫，還有跟他腦出血也會有相關。
# 病人覺得他的尿比較深，就有幫他驗一下看有沒有發炎的狀況。
# 有幫他會復健，之後就是固定要做物理跟職能治療。
# 他走上路上然後就跟機車擦撞，頭部就是有鈍傷，有一個血腫。
# 他如果要出院是已經可以出院了，之後就是到門診去追蹤。
# 要注意一下有沒有其他的頭部外傷的緊急狀況。
# 因為左側輸尿管結石，有到本院做碎石。
# 做完碎石之後，他還是覺得很痛，又會噁心嘔吐。
# 病人他有一些就預開的止痛，止痛針止痛藥，還有一些點滴之類的。
# 他待排一個胃鏡，還有要做頸超跟腹超，還要待拍一個心超。
# 他表示說他假如沒有排到胃鏡他就要出院，因為他覺得他不耐等。
# 病人要求要先出院，算是自動出院。
# 有幫他會心內，然後安排心超。
# 這次是今年一月因為右腳第二跟第四趾有擦傷傷口。
# 因為癒合差就來門診求治，發現右腳第二跟第四趾發黑。
# 經過醫生建議評估入院。
# 他在二十六號有去做過導管插入，就發現右髂骨動脈供血不足。
# 有給他用一公斤的紗帶加壓，目前沒有出血的現象。
# 醫師知道目前就先觀察。
# 他是高跌，沒有高壓，沒有過敏史。
# 過去病史有心律不整、高血壓、脊椎側彎開過刀。
# 這次是因為在家跌倒，導致右邊肋骨骨折入急診。
# 他的一些自備藥我們已經收回來，就會由護理人員發。
# 因為皮膚會癢，有開藥膏給他使用。
# 背部有紅疹，有開藥膏給他擦，不像是過敏反應。
# 這次主要就是因為右下腹痛來急診。
# 有一條尿管再開刀房的時候已經拔掉。
# 目前傷口就是三個洞，用紗布覆蓋。
# 這次主要就是因為腹痛、腹脹來急診。
# 上來的時候有放一條肛管。
# 這次就是因為騎機車跟機車發生擦撞。
# 會了骨科骨科，就說是右鎖骨骨折。
# 因為雙眼視力模糊所以想會眼科，有眼藥水在使用。
# 病人表示睡眠品質比較差，希望大夜班的時候不要量血壓。
# 這次是因為去年的時候左側乳癌有開過刀。
# 化療現在都已經結束了，預計明天出院。
# 術前有給他會過心臟內科。
# 造口師有教病人造口護理。
# 病人表示說他從肛門口還是有一點少量的出血，疑似是舊血。
# 造口師有把右側的人肛支撐棒拿掉，目前就是人肛待使用。
# 過去病史有高血壓、心臟病、中風，左側比較乏力、雙眼視野缺陷。
# 六月一號做大腸鏡，發現有直腸癌。
# 左手禁治療。
# 固定二四六中午在我們本院洗腎。
# 兩個禮拜前曾經做過心導管。
# 他有去做過雙側的頸動脈超音波，就說有中度的硬化。
# 雙側的背動脈灌流不足。
# 左心室比較肥大。
# 過去病史就左側乳癌開過刀，在右鎖骨有一個人工血管。
# 過去病史有失智、高血脂、情緒的疾病、膀胱結石。
# 診斷是沒有新的出血點。
# 因為二十三號開始吞嚥困難，建議會診神內。
# 待排頸動脈超音波跟頸動脈聲圖。
# 過去病史就是有高血壓、多囊腎、腦部積水開過刀。
# 醫師建議做膀胱造廔而住院。
# 他有很多的預開藥，有需要可以去電腦裡面點。
# 這次就是因為右下腹痛來急診。
# 注意一下小便自解情形。
# 二十八號肚臍那邊的傷口有一點紅。
# 左手骨折開刀過，右腳也是有骨折開刀過，然後鼻中膈彎曲開刀過。
# 其他傷口都很乾淨。
# 這次就是因為左邊的睪丸腫痛約十到十四天 。
# 他的過去病史有高膽固醇血症、右臀膿瘍開過刀。
# 這次就是一個星期前發現右臀膿瘍有做過切開引流。
# 過去病史有大腸癌開過刀、骨質疏鬆造成壓迫性骨折。
# 預計六月十九要做疝氣修補。
# 醫師看過以後就說給他傷口換藥，拔除鼻胃管就可以轉出普通病房。
# 他的過去病史有高血壓、胃潰瘍、重聽、狹心症。
# 到六月十號還是持續發燒，小夜班有燒到三十八度，就給他冰枕使用。
# 預計五月二號進去開刀房做乙狀結腸切除跟吻合術，加上腸造口手術。
# 眼科回覆就是沒有眼內膜炎，有開了藥水給他使用。
# 建議控制感染，然後繼續追蹤。
# 診斷是急性副睪炎。
# 切口疝氣跟臍疝氣、血管有鈣化、還有腸阻塞情形。
# 沒有高跌，沒有高壓，沒有過敏史。
# 會了外科，外科的建議是先做腸造口。
# 分別是在右橫膈下、腸吻合處、跟左橫膈下。
# 有一個人工肛門在左橫膈的地方。
# 五月十號已經重大傷病卡通過。
# 有長革蘭氏陰性桿菌。
# 有做過小腸攝影確定是有通的
# 電腦斷層顯示是沒有腹內膿瘍。
# 消化時間會蠻長的，每次反抽都還會有一些牛奶。
# 六月二十五號病人可以自己下床如廁。
# 因為病人一直很想從嘴巴吃，所以就讓他嘗試少量，沒有嗆咳。
# 這個病人需要翻身還有使用氣墊床。
# 這次入院是因為血尿的狀況。
# 之前尾骨開過刀、大腿骨折開過刀、有做過氣切。
# 這次的話是說他左腰痛然後到急診求診。
# 有幫他送到泌尿科門診那邊做碎石。
# 發現他左下輸尿管有結石然後還塞住。
# 病人進來之後就是打點滴，還有打止痛。
# 有幫他訂低普林的餐。
# 他以前有那個痛風跟腸穿孔的開刀過的病史。
# 他過年前曾經跌到造成左小腿傷口癒合不好，還有分泌物。
# 病人沒有發燒，傷口癒合也還不錯。
# 過去病史腎結石、子宮肌瘤、子宮外孕開過刀。
# 小夜有再幫他灌一次腸，還是有解大便。
# 這一次他自己騎機車自摔，左肋骨那邊會痛。
# 有看到他左肺是有浸潤的情形。
# 這一次進來他就說他下肢會抽痛，沒有辦法走遠，大概已經一個月。
# 他有一些自備藥就是開上去要服用。
# 拔掉之後就是有用紗帶兩公斤加壓，加壓到十一點半。
# 他的右腳不能彎曲。
# 診斷就是前列腺癌，還有神經性膀胱。
# 他是那個跌倒的高危險群，也是壓瘡高危險群。
# 有進行隔離，隔離到六月十八號才撤隔離。
# 病人在翻身的時候頭有去撞到那個床旁櫃。
# 有請家屬買紅藥水給他使用。
# 他那個膀胱造廔就是還是繼續給他接。
# 病人需要翻身，他有在約束，雙手手套加約束帶做約束。
# 他就是去年有氣喘，那時候住院然後發現說心臟的疾病。
# 有一直在吃藥，可是還是沒有改善。
# 有幫他做四肢動脈血流，沒有動脈阻塞的狀況。
# 有幫他做了心導管，就是阻塞的比較嚴重。
# 他下背部的傷口那時候就是有滲血，有幫他換藥。
# 之後病情比較穩定，就說準備幫他轉出來病房照顧。
# 有借拍痰墊，轉出來繼續使用。
# 有會復健，就是說之後可以做復健。
# 他的右下肺看起來有點花花的，還是有一些痰，要加強拍痰的部分。
# 他的右肺積水是有改善的。
# 病人可能用力還會有點滲尿。
# 結果就是格蘭性陽性跟陰性菌都都有都蠻多的。
# 診斷就說有肺挫傷還有右側氣血胸。
# 他那時候就是右上臂有瘀青的部分。
# 發現右側有氣胸，雙側肺頂葉多處肺泡。
# 他是直接接三腔的胸瓶，然後引流血水是少量的紅色血水。
# 有看到輕微的皮下氣腫但是肺部已經有擴張了，就讓他轉出加護病房。
# 小夜病人說他會胸背都會痛，有口服藥在吃。
# 他說過年後發現他有肺結核然後有在吃藥控制。
# 等他隔天出院之後，衛生所會再送到家裡來。
# 目前飲食有低磷鉀、低鹽五克。
# 他有心肥大跟雙側肺有痰。
# 營養師有教他飲食衛教，還有教他胰島素注射。
# 有給他頸圈預防性的使用。
# 過去病史有甲狀腺腫瘤、骨刺、膽結石開過刀。
# 開刀前有給他會診心臟血管科也做過心超，心超就是有二尖瓣脫垂。
# 醫師看過病人，表示今天可以開始喝流質並且至普通病房。
# 病人有隱名。
# 因為兩天前有癲癇、嘔吐、食慾不振的情形，來急診看過沒有改善。
# 照了胸超就是右側中間有肋膜積水，而且還有肺塌陷情形。
# 有請照服員教他拍背、換尿布、灌牛奶。
# 全身多處擦傷，左眼皮有血腫。
# 會診神外，醫師表示病情需要告病危。
# 這些傷口都用人工皮覆蓋，目前沒有壓傷情形。
# 病人有頭暈的情形，就是請他注意下床安全。
# 醫師看過就說胸管可以移除，然後繼續觀察。
# 有口服藥在吃，但是他覺得沒有改善。
# 病人還是很容易咳嗽。
# 那時候有幫病人會復健科，因為他四肢都比較無力。
# 這中間的血糖還是都偏高，有曾經高到五一八。
# 有做過腹超，沒有看到報告。
# 診斷是縱膈腔氣腫。
# 早上被棒球打到胸口，感到喉嚨痛不適來急診。
# 如果明天穩定的時候就可以轉病房。
# 呼吸淺快，暫時沒有痰液。
# 評估全身傷口完整，四肢末梢溫暖。
# 這次因為左大腿內側紅腫兩天有入急診。
# 病人上來後體溫一直不穩，有燒到三十九度。
# 這次是因為發燒、右腰痛、血尿來急診。
# 結果就是肝實質病變，還有脂肪肝。
# 肺功能就是重度呼吸道阻塞。
# 做完支氣管鏡醫生有特別交代注意病人是不是有發燒的情形。
# 資料已經傳給洗腎室，一、三、五洗腎。
# 懷疑縱膈淋巴結病變，還有輕微脾腫大。
# 沒有心包膜炎的情形所以可以開刀。
# 腹超報告是小腸阻塞，還有輕微脂肪肝。
# 腹部傷口就是紗布跟束腹帶使用。
# 呼吸比較喘大概三十一到三十八下。
# 因獨居問題有會了社福，社福表示轉出後會請看護。
# 有給他薄荷油使用。
# 過去病史有腎結石、胰臟炎、氣喘。
# 主述腹脹、腹痛、食慾差，所以來急診。
# 暫時沒有手術的必要。
# 解尿會痛，有灼熱感，沒有做什麼特別處理。
# 這次入院是因為頭暈、嘔吐、冒冷汗、血壓高。
# 他現在要做復健，每天十點半做物理，兩點半做職能。
# 小夜班嘔吐兩次，醫生都知道。
# 過去病史有尿路結石、剖腹產、輸尿管碎石、右側輸尿管狹窄開過刀。
# 上禮拜二門診追蹤發現一樣有右腎水腫。
# 上來的時候血糖有比較高，有給他上糖尿病藥在吃。
# 這次就是因為膀胱癌術後，上禮拜五開始排尿不順。
# 門診追蹤就拔除尿管，可是還是解的不是很好。
# 因為小便顏色蠻清，小便自解就出院。
# 自備藥的胃藥自付。
# 寶馬生漱口水在用。
# 牙科回覆就說急性根管發炎，有給他做口內檢查。
# 去做了胃鏡，就逆行性食道炎、表淺性胃炎、胃腫瘤。
# 就發現是胃癌且多處淋巴遠處轉移。
# 二尖瓣後葉活動有受限情形，還有輕微肺高壓。
# 六月十四號做次全胃切除，採全麻。
# 身上沒有壓傷情形，臀部有色素沉著。
# 頸部有乾癬，會皮膚科就說有尋常性皮膚病。
# 因為右上腹痛直接去門診。
# 就說右升結腸憩室炎有化膿。
# 會外科表示要抗生素治療。
# 右下腹有疼痛情形，就轉外科病房照護。
# 每次小便完都有少量黃糊便。
# 醫生知道就說觀察。
# 上周到門診做過碎石未改善，所以就再進來開刀。
# 六月二十號去做微創玻璃體切除手術跟光線凝固治療玻璃體內注射。
# 這次因為左眼視力模糊數月到門診求治。
# 術前要每五分鐘滴一次，總共滴六次散瞳劑。
# 小夜班再給他抽鈉離子跟鉀還有尿酸。
# 如果不需要使用，出院拿回去放就可以。
# 測試有回血，沒有腫也沒有滲漏。
# 過去病史左肱骨骨折開過刀、雙眼白內障開過刀。
# 自備藥可以自服。
# 這次是因為長期鼻塞、睡眠容易打呼，影響睡眠品質。
# 過去病史氣喘，跟左鶻骨骨折開過刀。
# 車禍導致左足被擦傷，跟右大腿撕裂傷。
# 左大腿內側有大片的瘀青，醫生知道冰敷就好。
# 過去病史右側小耳症開過刀、膀胱結石跟做過碎石。
# 因為解尿困難血尿，上個月至門診做過碎石。
# 訂餐已經幫他訂了。
# 六月二十二號去做內視鏡取石術。
# 這次是因為右腰痛一個禮拜，門診建議開刀而入院。
# 過去病史腰椎開過刀、右髖人工關節、還有腎水泡。
# 平時有服用抗凝血劑。
# 右臀部有個九乘以三的發紅，壓可以反白。
# 因為病情穩定轉病房觀察。
# 這次是因為勃起時穿褲子的時候，不小心導致陰莖骨折。
# 有給他做男性外生殖器的超音波。
# 這個是膽結石合併膽囊炎。
# 因為六月初開始上腹痛到後背，做了腹部超音波檢查發現有膽結石。
# 有尿意尿不出來，但膀胱不脹。
# 醫生知道不用做特別處理，之後開始排氣了。
# 他是家屬陪同進來。
# 膀胱癌開刀之後排尿困難跟解尿疼痛不適。
# 去做內視鏡雷射手術，現在已經開完了。
# 病人說想要吃軟便藥，醫生沒有開。
# 這次是因為左下腹突出約一周，微痛可推回。
# 病人表示自備藥可否吃，醫生表示先不吃沒關係。
# 這次因為肛門結節兩到三個月，偶有出血情形，會癢無痛感。
# 醫生建議進來做電燒術。
# 這個病人診斷是病毒疣。
# 過去病史右手無名指骨折開過刀，左側精索靜脈屈張開過刀。
# 這次因為肛門廔管進來，肛門腫痛有出血情形。
# 開刀在肛門口放紗布條，六小時後可以移除。
# 右下肢長期站立脹痛，診斷靜脈曲張。
# 去開了高位結紮術還有血管結紮手術。
# 這次是因為雙眼雷射手術還是感到視力模糊。
# 去開了水晶體切除手術。
# 眼紗布眼罩固定。
# 知道後沒有特別作處理。
# 過去病史，雙眼白內障開過刀，心臟病，腸穿孔開過三次刀。
# 診斷為右腳蜂窩性組織炎。
# 因為右下肢紅腫出院返家後有口服抗生素使用。
# 右小腿傷口二乘一公分右腳踝傷口一乘一公分，紗布覆蓋。
# 送來之後體溫三十八點四，陸續一直在躺冰枕。
# 主訴右小腿偶有抽動情形。
# 因為一直發燒不退，有會診感染科。
# 建議會免疫科，然後安排關節的超音波。
# 唾液腺腫瘤開過刀。
# 一個月前因解血便至門診求治，建議做大腸鏡入院治療。
# 術前抽血沒有特別的異常。
# 雙手指關節有紅腫，是乾燥造成的。
# 因為發燒腹痛，雙腰疼痛入急診。
# 左側水腎，左側尿路結石。
# 病人說外陰唇疼痛想要擦藥。
# 陰唇破皮所以給他開了藥膏。
# 過去病史腦幹出血、憂鬱症、左膝蓋人工關節、脊椎開過刀。
# 臉部跟胸前有紅疹，是因為打化療藥引起的。
# 過去病史氣喘及退化性關節炎、臀部膿瘍開過刀、雙眼白內障開過刀。
# 這次是因為副睪丸炎進來，右側睪丸開始腫痛。
# 雙側的甲狀腺腫已經二十年左右。
# 車禍後，右膝跟右腳背擦傷，傷口越來越腫。
# 昨天晚上疼痛跟紅疹加劇到門診求診。
# 左腹股溝疝氣已經一年多，疼痛加劇。
# 門診追蹤建議開刀而入院。
# 據交班表示病人沒有過去病史。
# 手術史的話就是雙膝因車禍手術所以有裝過鋼釘。
# 至台北馬偕醫院求治，表示右側有氣胸。
# 因為沒有病床所以就先來我們台北醫院。
# 診斷有第一跟第四肋骨骨折及右側氣胸。
# 急診的話醫生有給病人說明病情，告知病危。
# 填寫入加護病房的同意書，病人可接受。
# 身上多處有撕裂傷，分別在右手背、右手肘、左手背、左手肘，右膝跟左膝。
# 右胸氣胸有改善，所以就轉到普通病房。
# 沒有高跌，沒有高壓，對不詳的東西會過敏。
# 診斷出是右腳背蜂窩性組織炎。
# 主訴說有左胸纖維瘤開過刀、手汗症開過刀、汗泡疹。
# 曾經有對巧克力還有鮮奶油的過敏史。
# 被塑膠箱子砸傷，右腳背就是紅腫熱痛、右膝就有瘀青。
# 在家中有發燒的情形，自行吃過普拿疼。
# 有抽過糖化血紅素，然後血糖曾經有到三百三。
# 病人有請假。
# 過去病史脊椎開刀過、做過內視鏡、膀胱癌開過刀。
# 因解血尿兩周，有頭暈、呼吸的時候會喘。
# 因為病人之前輸血會過敏，請我們使用自費同意書，換成輸血過濾器。
# 這邊就說左邊有中度的輸尿管積水。
# 腎上腺體有髓性脂肪瘤。
# 這裡是膀胱盥洗的事情。
# 過去病史就是心臟開過刀，心包膜開過刀，背部肉瘤開過刀，攝護腺開過刀，疝氣開過刀。
# 右側腹股溝痛已三天。
# 肚臍上方有氣腫，然後右下腹突起。
# 右下腹和陰囊都是腫的。
# 因發燒、嘔吐、雙下肢水腫入急診。
# 經醫生診斷後轉普通病房。
# 這裡就是止痛貼片的事情。
# 病人剛開始入院的時候自己有止痛貼片。
# 他的心臟運動功能減退，二尖瓣狹窄。
# 疑似是缺血性的心臟病。
# 有調配精油給病人用。
# 這邊就是腹脹，薄荷油可以用。
# 醫生口頭說可以讓病人吃流質食物。
# 抬高之後測量的話體溫三十七度，然後脈搏八十，呼吸十九。
# 家屬表示說如果病人有任何狀況不管多晚都要通知他們。
# 他們希望最後可以陪在病人身邊。
# 口頭說可吃米湯、粥、布丁，牛奶不要。
# 大夜班的時候有發燒，所以就只有冰枕使用。
# 如果有滲漏就墊紗布。
# 病人的家屬有來跟我們要病人的一些電腦報告跟一些病例。
# 家屬代訴有胃潰瘍、十二指腸潰瘍、腎臟病、肺積水、低血鈉、泌尿道感染、膽切除等過去病史。
# 雙下肢紅腫起水泡且有破裂情形到急診求治。
# 因為痔瘡，上禮拜肛門處腫，斷斷續續出現有分泌物。
# 這次是因為大腸憩室炎。
# 今晚突然感到解尿困難及有血尿情形就入急診。
# 自備藥我們發，但病人說他拒吃。
# 他是膽結石跟缺鐵性貧血，由家屬跟工友推輪椅入病房。
# 曾至本院門診求治住院。
# 去做了膽囊切除術，全身麻醉沒有輸血。
# 給他左肩會痛擦的創痛藥膏。
# 過去病史是十二指腸潰瘍開過刀、痔瘡開過刀，攝護腺肥大開過刀。
# 後來有給他三角巾使用。
# 因為膽囊炎，上腹部會痛。
# 沒有跌倒、沒有壓瘡、可以正常吃。
# 病人以為是痔瘡發作，後來腫瘤越長越大而且會癢。
# 診斷是右下肢燙傷、蜂窩性組織炎。
# 自訴有血管阻塞、雙側卵巢開過刀、腦出血的過去病史。
# 因為三天前被蒸汽管燙傷右大腿及小腿到急診。
# 急診打過抗生素、藥膏。
# 病人採極低渣飲食。
# 過去病史有唾液腺腫瘤開過刀、大腸息肉。
# 因為息肉的位置太高，所以醫生建議開刀住院。
# 病人主訴說臉、前胸、背部有長痘痘，是因為藥物的副作用。
# 術後有放一條尿管，目前就是生理食鹽水沖洗。
# 這次是因為右大拇指的傷口已經一年多癒合不了，所以住院做清創。
# 傷口就是優點、紗布、彈繃使用，患處抬高。
# 晚上因為病人睡不好有給他助眠藥。
# 醫生有給他開鎮靜安眠的藥讓病人輔助睡覺。
# 十七號說腹脹有給過薄荷油使用。
# 這次是左腹股溝有突出一到兩周，微痛可推回。
# 這次是因為三年前廔管開完刀收口一直癒合不了、反覆發作。
# 這次是因為便祕自行在家灌腸，後來因為有膿瘍流出、疼痛加遽。
# 紗布、石蠟、優膏使用。
# 病人在雙和做過電療、腦震盪、右腹造口。
# 此次是因為肛門膿瘍，腫大概兩個禮拜。
# 這次是因為他鋸樹木的時候被鋸刀鋸到左手前臂及左前胸。
# 目前抗生素使用，無氣血胸的情形。
# 右眼外傷性白內障、晶體溶解性青光眼。
# 因為三天前右眼被鐵絲刺傷，視力模糊及頭痛入本院治療。
# 去做水晶體囊外切除術，改成人工的水晶體。
# 病人的過去病史有肺積水、肺炎，他有胰臟腫瘤。
# 病人突然間燒到三十八點二，血氧掉到八十八到九十一。
# 病人說他顳葉兩側頭痛非常厲害影響到他睡眠的品質。
# 隔天的早上尿尿有血塊醫生知道。
# 因為背部瘀青非常腫，所以有給過抗瘀腫得藥膏。
# 病人說後臂處有一個血腫，但發現沒有出血情形先觀察。
# 輸血當中因為病人覺得畏寒，體溫飆到三十七點八，所以冰枕使用。
# 診斷是胰臟切除術後胰臟炎，一點點的膀胱炎。
# 左肋膜積水，所以安排做胸腔的檢查。
# 胸腔穿刺後有送細胞學的外送檢查。
# 胸超抽出來的胸水是深褐色，右肋膜的積水有比較改善了。
# 過去病史有腎積水、腎結石、氣喘、失智、白內障開過刀、右耳失聰。
# 會了外科是說升結腸及橫結腸有憩室炎。
# 隔天早上說吃了早餐之後吐了兩次胃酸。
# 心臟肥大、慢性的雙側肺纖維化。
# 他自己本身有支氣管擴張的鼻噴劑，病人會使用。
# 因為睡不好的關係，有會精神科，就是先觀察。
# 這次是因為膀胱頸狹窄，解尿困難，所以就門診進來。
# 因為影響日常生活，門診來求治。
# 因為喉嚨痛吞嚥困難大概十天，去診所看沒有改善。
# 目前是寶馬漱口水使用，自備藥自己服用。
# 病人因為左下排的牙齒會疼痛預計下禮拜二要回牙科門診繼續追蹤。
# 這次住院是因為騎腳踏車撞到水溝蓋自摔，頭部有撕裂傷。
# 這次是因為禮拜二出車禍，右腳踝、大腿擦傷來急診，門診追蹤。
# 他吃完海鮮之後右手背開始紅腫熱痛來急診。
# 內分泌是建議病人要補充水分，然後採低普林飲食跟糖尿病衛教。
# 左右頸的深部有感染，右臉診斷是蜂窩性組織炎。
# 因為右臉腫脹大概兩個禮拜，又有伴隨發燒的情形。
# 內科感染回覆是說病人是金黃色葡萄球菌感染的。
# 醫生懷疑跟腮腺炎有關係。
# 氣墊床使用、右手要約束。
# 這次是因為右乳房處有個紅腫、流膿大概兩天左右。
# 請皮膚科開藥膏、隔離保護。
# 今年三月份因為要去開頸椎，照了頸椎發現四、五、六骨刺。
# 做了兩次化療之後因為五天前右側的泡疹有發作的情形，無法再做第三次的化療，要轉安寧療房。
# 因為中間疼痛的關係所以他有嗎啡皮下注射。
# 病人呼吸費力、一直覺得不舒服。
# 因為有病毒泡疹，藥膏已經有開一條給病人使用。
# 小夜班病人一直咳嗽，咳嗽中帶有血絲。
# 目前病人的頭部、耳後的泡疹是紗布覆蓋，然後藥膏使用。
# 病人談到說他是宗教的慈濟的教會，所以他是慈濟的會員。
# 他說是被魚的魚刺刺到，他的左手背就是紅腫熱痛。
# 這次是因為頭暈、走路會偏、噁心吃不下，大概兩個禮拜。
# 病人過去病史有鼻竇炎開過刀。
# 泌尿科的回覆是說他是右側的腎臟結石。
# 鈣離子的症狀就是會頭暈、昏睡、嘔吐。
# 因為凌晨開始發燒跟頭痛感到不適，到門診追蹤所以就進來。
# 過去病史甲狀腺開過刀跟尿路結石開過刀，還有重聽。
# 化療做完，之後拔針就可以出院。
# 病理報告是惡性的，醫生建議入院。
# 主訴有解一次糊便，之後就比較好。
# 打完針之後眼睛會紅，病人說之前藥物過敏就是此症狀。
# 有高血脂、糖尿病、左腋下有開過脂肪瘤還有肺炎。
# 對磺胺類的藥物過敏。
# 有風濕性心臟病開過刀做過二尖瓣置換、舌癌開過刀。
# 自備的心臟藥說可以自服，但是沒有藥名所以先不吃。
# 因為去年底健檢發現雙側甲狀腺結節，到門診追蹤就建議進來開甲狀腺切除。
# 因為被陌生人用球棒及刀類亂打導致身上多處傷口入急診。
# 有高血壓、心臟病、氣喘跟右側乳房脂肪瘤開過刀。
# 左側門牙有斷裂、左手中指有變形、全身很多傷口。
# 第二十一、二十二、二十三顆牙齒牙冠有骨折。
# 牙齒有裂縫，建議口腔檢查。
# 這個是低血鉀、感染性腸炎的病人。
# 腹超就說肝實質病變，還有懷疑慢性胰臟炎。
# 過去病史有憂鬱症、右膝換過人工關節。
# 因為洗澡跌坐在地面導致右手沒辦法動沒辦法出力。
# 病人本身有妄想症，之後會診精神科。
# 要有智能評估跟失智評估之後才能開立，本院沒辦法開。
# 有胃潰瘍、闌尾炎開過刀、雙眼近視病史。
# 診斷是左臉蜂窩性組織炎、腮腺炎。
# 如果又喘的話就必須停藥，但之後就沒再喘了。
# 在無疼痛下實施有效治療須告知。
# 尾底骨有兩處兩度壓傷，還有一個三度壓傷。
# 有長糞腸球菌，所以給他隔離。
# 病人全拒，包括抽血、輸血、胃鏡，全部都不要。
# 尿只有一點點，感覺有血塊，有點小流血。
# 建議先治療現況，再處理抑鬱的情形。
# 過去病史有甲狀腺腫瘤、骨刺、膽結石開過刀。
# 因慢性扁桃腺炎長期喉嚨痛不適，建議入院。
# 因為之前有腦出血所以右側乏力。
# 這次進來做化療，右腹人肛還在。
# 如果病人痛的話就可以直接接點滴打。
# 平躺會胸悶，所以就給他半坐臥。
# 有異位性皮膚炎的過去病史、右耳積水開過刀、割包皮開過刀。
# 單導餘尿有膿尿跟白血球增多的情形，所以給他會診泌尿科。
# 臨床上有需要的話要再開單送檢。
# 因為從三十公分高梯子往後摔，頭皮紅腫頸部痛，右手麻。
# 過去病史心律不整、胃食道逆流、膽結石開過刀、雙眼白內障開過刀。
# 沒有雙側顱外頸動脈和輕度動脈粥狀硬化。
# 雙側椎動脈流速體積是足夠的。
# 病人有驗安非他命，巴比妥酸鹽，古柯鹼，毒物美沙酮嗎啡之類的。
# 病人重聽有給他戴了右耳助聽器。
# 在台大做過化療、小腸腫瘤開過刀、淋巴腫瘤開過刀、胃潰瘍。

# %%
with open("病歷500句子.txt", "r",encoding="utf-8") as f:
    f_content = f.read()
    #print(f_content)
    
    #print("\n")
    print("整份文檔的長度 in bytes: " + str(f.tell()))  # 整份文檔的長度 in bytes
    print("整份文檔的長度 in Chinese characters: " + str(len(f_content))) # 整份文檔的長度 in Chinese characters
    print("平均每顆中文字用掉多少 butes: " + str(f.tell()/len(f_content)))
# Out:
# 整份文檔的長度 in bytes: 30122
# 整份文檔的長度 in Chinese characters: 10215
# 平均每顆中文字用掉多少 butes: 2.9488007831620164

# %%
'''
我從 google news 隨意貼了一則新聞，結果發現其中遇到阿拉伯數字
是用一個 byte 編碼，造成我每跳2個 bytes 的方法，會發生解碼錯誤，
於是我將新聞中出現的阿拉伯數字全部改為國字

? 我發覺雖然我每次的 read_count = 2, 
但是每次 seek() 並不是兩個 bytes 的距離跳的，
有的時候的確是 2，如數字，但是大部份的時候是 6 (莫非兩顆用 utf-8編碼的中文是用 3個 bytes?)
'''
with open("news.txt", "r", encoding='utf-8') as f:
    f_whole = f.read()
    print(len(f_whole))
    print(f_whole) # 先印出來
    
    f.seek(0)  # 從頭來看
    read_count = 2 # 每次讀兩顆「字」
    vac = dict() # 準備用來記錄 「兩顆字」構成的「詞」的出現頻率-- (詞：2)
    print(f.tell())
    f_content = f.read(read_count)
    while len(f_content) > 0:
        print("->" + f_content)
        print(f.tell())
        f_content = f.read(read_count)
        if f_content in vac.keys():  # 每次將新讀到的「兩顆字」的「詞」當作 key
            vac[f_content] += 1
        else:
            vac[f_content] = 1
# Out:
# 1192
# 石齊平》美國霸權的核心危機
# 18:212020/09/26 言論 石齊平
#
# 中美全球大博弈是人類21世紀的頭號歷史事件，目前雙方正在綜合國力（含經濟、工業、金融、科技、軍事、國際影響力等）及地緣戰略板塊兩個方面展開激烈競爭與衝撞，或遲或早，一段時間之後，將會出現勝負結果。如果美方落敗，意味著美國霸權運勢出現轉折，開始下行；如果中方落敗，意味著美國霸權地位仍將存續，但不意味著美國霸權不存在危機。換言之，各種現象顯示，美國霸權的核心危機已然存在，中美兩強博弈的過程與結果，影響的只是美國霸權由盛轉衰轉折點出現的遲或早而已。
#
# 觀察美國霸權從1918年一戰結束綜合國力全面超過英國開始，迄今（2020年）為止一個世紀的發展壯大過程，從原本的孤立主義到開始參與國際事務，再到1945年二戰後的對國際社會的貢獻，贏得國際社會的普遍肯定與尊重，憑恃的是美國體制與美國價值。美國體制與美國價值不僅讓美國本身資源不斷地釋放出巨大的能量與活力，而且也化約成一種「美國夢」，成了人類發展進步的重要標竿，並因此吸納了全球人才前往美國，進一步強化了美國的霸權基礎。
#
# 在這個意義上，美國霸權的形成與發展，有著如下的因果關係或順序：一、美國體制與價值，充實與壯大了；二、美國的綜合國力，並因此以此為後盾，實現了；三、美國在全球範圍中巨大的國家利益（經濟、金融、軍事、資源、情報…），最終完成了美國的世紀霸業。
#
# 然而，美國作為一個強國，畢竟也逃避不了任何一個強國盛極而衰的必然邏輯。進入到21世紀之後，以美國首屈一指的強大軍力並不能讓美國贏得漂亮的反恐戰爭，以美國睥睨全球的金融實力並不能讓美國倖免於一場世紀金融海嘯；如今，美國為了維持霸權地位，竟不擇手段、不顧形象地對位居第二的中國，展開前所未見的毀滅性攻擊，所有這些，其實對美國自身都造成了極大的傷害—美國的體制與價值正在被美國自身的行為自殘。
#
# 很多人以為，這一切或許跟個別的政治人物尤其是川普總統有關，這應該是一個巨大的誤區。川普作為一個政客，行事蠻橫，有小聰明無大智慧，還極端自私，這都是事實。但必須同時看到，美國的政治體制怎麼能夠容許這麼一個獨行其事的領導人為所欲為，未受任何有效的監督與制衡，甚至美國最自豪的司法獨立與貨幣獨立也可以被此一獨夫肆意踐踏破壞，美國的兩黨輪替已淪為不問是非的兩黨惡鬥，美國的代議政治也異化成了各大利益集團的交易政治，甚至連美國最自詡的選舉政治，無論其制度設計、過程與結果，不但再受質疑，而且還可能成為政治亂源。
#
# 體制之外，貧富差距、種族矛盾、華爾街壟斷等也在在折射出了美國價值，比如公平、正義、民主、法治、博愛、人權等的偽善。所有這一切，才是美國霸權的核心危機，說到底，這又都與文化有關。歷史學家湯恩比在上世紀說，人類21世紀的前途看中國，或許正是從這個角度深刻觀察的判斷。
#
# （作者為香港鳳凰衛視台資深評論員）
# 0
# ->石齊
# 6
# ->平》
# 12
# ->美國
# 18
# ->霸權
# 24
# ->的核
# 30
# ->心危
# 36
# ->機
#
# 41
# ->18
# 43
# ->:2
# 45
# ->12
# 47
# ->02
# 49
# ->0/
# 51
# ->09
# 53
# ->/2
# 55
# ->6
# 57
# ->言論
# 63
# -> 石
# 67
# ->齊平
# 18446744073709551690
# ->
#
#
# 77
# ->中美
# 83
# ->全球
# 89
# ->大博
# 95
# ->弈是
# 101
# ->人類
# 107
# ->21
# 109
# ->世紀
# 115
# ->的頭
# 121
# ->號歷
# 127
# ->史事
# 133
# ->件，
# 139
# ->目前
# 145
# ->雙方
# 151
# ->正在
# 157
# ->綜合
# 163
# ->國力
# 169
# ->（含
# 175
# ->經濟
# 181
# ->、工
# 187
# ->業、
# 193
# ->金融
# 199
# ->、科
# 205
# ->技、
# 211
# ->軍事
# 217
# ->、國
# 223
# ->際影
# 229
# ->響力
# 235
# ->等）
# 241
# ->及地
# 247
# ->緣戰
# 253
# ->略板
# 259
# ->塊兩
# 265
# ->個方
# 271
# ->面展
# 277
# ->開激
# 283
# ->烈競
# 289
# ->爭與
# 295
# ->衝撞
# 301
# ->，或
# 307
# ->遲或
# 313
# ->早，
# 319
# ->一段
# 325
# ->時間
# 331
# ->之後
# 337
# ->，將
# 343
# ->會出
# 349
# ->現勝
# 355
# ->負結
# 361
# ->果。
# 367
# ->如果
# 373
# ->美方
# 379
# ->落敗
# 385
# ->，意
# 391
# ->味著
# 397
# ->美國
# 403
# ->霸權
# 409
# ->運勢
# 415
# ->出現
# 421
# ->轉折
# 427
# ->，開
# 433
# ->始下
# 439
# ->行；
# 445
# ->如果
# 451
# ->中方
# 457
# ->落敗
# 463
# ->，意
# 469
# ->味著
# 475
# ->美國
# 481
# ->霸權
# 487
# ->地位
# 493
# ->仍將
# 499
# ->存續
# 505
# ->，但
# 511
# ->不意
# 517
# ->味著
# 523
# ->美國
# 529
# ->霸權
# 535
# ->不存
# 541
# ->在危
# 547
# ->機。
# 553
# ->換言
# 559
# ->之，
# 565
# ->各種
# 571
# ->現象
# 577
# ->顯示
# 583
# ->，美
# 589
# ->國霸
# 595
# ->權的
# 601
# ->核心
# 607
# ->危機
# 613
# ->已然
# 619
# ->存在
# 625
# ->，中
# 631
# ->美兩
# 637
# ->強博
# 643
# ->弈的
# 649
# ->過程
# 655
# ->與結
# 661
# ->果，
# 667
# ->影響
# 673
# ->的只
# 679
# ->是美
# 685
# ->國霸
# 691
# ->權由
# 697
# ->盛轉
# 703
# ->衰轉
# 709
# ->折點
# 715
# ->出現
# 721
# ->的遲
# 727
# ->或早
# 733
# ->而已
# 739
# ->。
#
# 744
# ->
# 觀
# 749
# ->察美
# 755
# ->國霸
# 761
# ->權從
# 767
# ->19
# 769
# ->18
# 771
# ->年一
# 777
# ->戰結
# 783
# ->束綜
# 789
# ->合國
# 795
# ->力全
# 801
# ->面超
# 807
# ->過英
# 813
# ->國開
# 819
# ->始，
# 825
# ->迄今
# 831
# ->（2
# 835
# ->02
# 837
# ->0年
# 841
# ->）為
# 847
# ->止一
# 853
# ->個世
# 859
# ->紀的
# 865
# ->發展
# 871
# ->壯大
# 877
# ->過程
# 883
# ->，從
# 889
# ->原本
# 895
# ->的孤
# 901
# ->立主
# 907
# ->義到
# 913
# ->開始
# 919
# ->參與
# 925
# ->國際
# 931
# ->事務
# 937
# ->，再
# 943
# ->到1
# 947
# ->94
# 949
# ->5年
# 953
# ->二戰
# 959
# ->後的
# 965
# ->對國
# 971
# ->際社
# 977
# ->會的
# 983
# ->貢獻
# 989
# ->，贏
# 995
# ->得國
# 1001
# ->際社
# 1007
# ->會的
# 1013
# ->普遍
# 1019
# ->肯定
# 1025
# ->與尊
# 1031
# ->重，
# 1037
# ->憑恃
# 1043
# ->的是
# 1049
# ->美國
# 1055
# ->體制
# 1061
# ->與美
# 1067
# ->國價
# 1073
# ->值。
# 1079
# ->美國
# 1085
# ->體制
# 1091
# ->與美
# 1097
# ->國價
# 1103
# ->值不
# 1109
# ->僅讓
# 1115
# ->美國
# 1121
# ->本身
# 1127
# ->資源
# 1133
# ->不斷
# 1139
# ->地釋
# 1145
# ->放出
# 1151
# ->巨大
# 1157
# ->的能
# 1163
# ->量與
# 1169
# ->活力
# 1175
# ->，而
# 1181
# ->且也
# 1187
# ->化約
# 1193
# ->成一
# 1199
# ->種「
# 1205
# ->美國
# 1211
# ->夢」
# 1217
# ->，成
# 1223
# ->了人
# 1229
# ->類發
# 1235
# ->展進
# 1241
# ->步的
# 1247
# ->重要
# 1253
# ->標竿
# 1259
# ->，並
# 1265
# ->因此
# 1271
# ->吸納
# 1277
# ->了全
# 1283
# ->球人
# 1289
# ->才前
# 1295
# ->往美
# 1301
# ->國，
# 1307
# ->進一
# 1313
# ->步強
# 1319
# ->化了
# 1325
# ->美國
# 1331
# ->的霸
# 1337
# ->權基
# 1343
# ->礎。
# 1349
# ->
#
#
# 1353
# ->在這
# 1359
# ->個意
# 1365
# ->義上
# 1371
# ->，美
# 1377
# ->國霸
# 1383
# ->權的
# 1389
# ->形成
# 1395
# ->與發
# 1401
# ->展，
# 1407
# ->有著
# 1413
# ->如下
# 1419
# ->的因
# 1425
# ->果關
# 1431
# ->係或
# 1437
# ->順序
# 1443
# ->：一
# 1449
# ->、美
# 1455
# ->國體
# 1461
# ->制與
# 1467
# ->價值
# 1473
# ->，充
# 1479
# ->實與
# 1485
# ->壯大
# 1491
# ->了；
# 1497
# ->二、
# 1503
# ->美國
# 1509
# ->的綜
# 1515
# ->合國
# 1521
# ->力，
# 1527
# ->並因
# 1533
# ->此以
# 1539
# ->此為
# 1545
# ->後盾
# 1551
# ->，實
# 1557
# ->現了
# 1563
# ->；三
# 1569
# ->、美
# 1575
# ->國在
# 1581
# ->全球
# 1587
# ->範圍
# 1593
# ->中巨
# 1599
# ->大的
# 1605
# ->國家
# 1611
# ->利益
# 1617
# ->（經
# 1623
# ->濟、
# 1629
# ->金融
# 1635
# ->、軍
# 1641
# ->事、
# 1647
# ->資源
# 1653
# ->、情
# 1659
# ->報…
# 1665
# ->），
# 1671
# ->最終
# 1677
# ->完成
# 1683
# ->了美
# 1689
# ->國的
# 1695
# ->世紀
# 1701
# ->霸業
# 1707
# ->。
#
# 1712
# ->
# 然
# 1717
# ->而，
# 1723
# ->美國
# 1729
# ->作為
# 1735
# ->一個
# 1741
# ->強國
# 1747
# ->，畢
# 1753
# ->竟也
# 1759
# ->逃避
# 1765
# ->不了
# 1771
# ->任何
# 1777
# ->一個
# 1783
# ->強國
# 1789
# ->盛極
# 1795
# ->而衰
# 1801
# ->的必
# 1807
# ->然邏
# 1813
# ->輯。
# 1819
# ->進入
# 1825
# ->到2
# 1829
# ->1世
# 1833
# ->紀之
# 1839
# ->後，
# 1845
# ->以美
# 1851
# ->國首
# 1857
# ->屈一
# 1863
# ->指的
# 1869
# ->強大
# 1875
# ->軍力
# 1881
# ->並不
# 1887
# ->能讓
# 1893
# ->美國
# 1899
# ->贏得
# 1905
# ->漂亮
# 1911
# ->的反
# 1917
# ->恐戰
# 1923
# ->爭，
# 1929
# ->以美
# 1935
# ->國睥
# 1941
# ->睨全
# 1947
# ->球的
# 1953
# ->金融
# 1959
# ->實力
# 1965
# ->並不
# 1971
# ->能讓
# 1977
# ->美國
# 1983
# ->倖免
# 1989
# ->於一
# 1995
# ->場世
# 2001
# ->紀金
# 2007
# ->融海
# 2013
# ->嘯；
# 2019
# ->如今
# 2025
# ->，美
# 2031
# ->國為
# 2037
# ->了維
# 2043
# ->持霸
# 2049
# ->權地
# 2055
# ->位，
# 2061
# ->竟不
# 2067
# ->擇手
# 2073
# ->段、
# 2079
# ->不顧
# 2085
# ->形象
# 2091
# ->地對
# 2097
# ->位居
# 2103
# ->第二
# 2109
# ->的中
# 2115
# ->國，
# 2121
# ->展開
# 2127
# ->前所
# 2133
# ->未見
# 2139
# ->的毀
# 2145
# ->滅性
# 2151
# ->攻擊
# 2157
# ->，所
# 2163
# ->有這
# 2169
# ->些，
# 2175
# ->其實
# 2181
# ->對美
# 2187
# ->國自
# 2193
# ->身都
# 2199
# ->造成
# 2205
# ->了極
# 2211
# ->大的
# 2217
# ->傷害
# 2223
# ->—美
# 2229
# ->國的
# 2235
# ->體制
# 2241
# ->與價
# 2247
# ->值正
# 2253
# ->在被
# 2259
# ->美國
# 2265
# ->自身
# 2271
# ->的行
# 2277
# ->為自
# 2283
# ->殘。
# 2289
# ->
#
#
# 2293
# ->很多
# 2299
# ->人以
# 2305
# ->為，
# 2311
# ->這一
# 2317
# ->切或
# 2323
# ->許跟
# 2329
# ->個別
# 2335
# ->的政
# 2341
# ->治人
# 2347
# ->物尤
# 2353
# ->其是
# 2359
# ->川普
# 2365
# ->總統
# 2371
# ->有關
# 2377
# ->，這
# 2383
# ->應該
# 2389
# ->是一
# 2395
# ->個巨
# 2401
# ->大的
# 2407
# ->誤區
# 2413
# ->。川
# 2419
# ->普作
# 2425
# ->為一
# 2431
# ->個政
# 2437
# ->客，
# 2443
# ->行事
# 2449
# ->蠻橫
# 2455
# ->，有
# 2461
# ->小聰
# 2467
# ->明無
# 2473
# ->大智
# 2479
# ->慧，
# 2485
# ->還極
# 2491
# ->端自
# 2497
# ->私，
# 2503
# ->這都
# 2509
# ->是事
# 2515
# ->實。
# 2521
# ->但必
# 2527
# ->須同
# 2533
# ->時看
# 2539
# ->到，
# 2545
# ->美國
# 2551
# ->的政
# 2557
# ->治體
# 2563
# ->制怎
# 2569
# ->麼能
# 2575
# ->夠容
# 2581
# ->許這
# 2587
# ->麼一
# 2593
# ->個獨
# 2599
# ->行其
# 2605
# ->事的
# 2611
# ->領導
# 2617
# ->人為
# 2623
# ->所欲
# 2629
# ->為，
# 2635
# ->未受
# 2641
# ->任何
# 2647
# ->有效
# 2653
# ->的監
# 2659
# ->督與
# 2665
# ->制衡
# 2671
# ->，甚
# 2677
# ->至美
# 2683
# ->國最
# 2689
# ->自豪
# 2695
# ->的司
# 2701
# ->法獨
# 2707
# ->立與
# 2713
# ->貨幣
# 2719
# ->獨立
# 2725
# ->也可
# 2731
# ->以被
# 2737
# ->此一
# 2743
# ->獨夫
# 2749
# ->肆意
# 2755
# ->踐踏
# 2761
# ->破壞
# 2767
# ->，美
# 2773
# ->國的
# 2779
# ->兩黨
# 2785
# ->輪替
# 2791
# ->已淪
# 2797
# ->為不
# 2803
# ->問是
# 2809
# ->非的
# 2815
# ->兩黨
# 2821
# ->惡鬥
# 2827
# ->，美
# 2833
# ->國的
# 2839
# ->代議
# 2845
# ->政治
# 2851
# ->也異
# 2857
# ->化成
# 2863
# ->了各
# 2869
# ->大利
# 2875
# ->益集
# 2881
# ->團的
# 2887
# ->交易
# 2893
# ->政治
# 2899
# ->，甚
# 2905
# ->至連
# 2911
# ->美國
# 2917
# ->最自
# 2923
# ->詡的
# 2929
# ->選舉
# 2935
# ->政治
# 2941
# ->，無
# 2947
# ->論其
# 2953
# ->制度
# 2959
# ->設計
# 2965
# ->、過
# 2971
# ->程與
# 2977
# ->結果
# 2983
# ->，不
# 2989
# ->但再
# 2995
# ->受質
# 3001
# ->疑，
# 3007
# ->而且
# 3013
# ->還可
# 3019
# ->能成
# 3025
# ->為政
# 3031
# ->治亂
# 3037
# ->源。
# 18446744073709554660
# ->
#
#
# 3047
# ->體制
# 3053
# ->之外
# 3059
# ->，貧
# 3065
# ->富差
# 3071
# ->距、
# 3077
# ->種族
# 3083
# ->矛盾
# 3089
# ->、華
# 3095
# ->爾街
# 3101
# ->壟斷
# 3107
# ->等也
# 3113
# ->在在
# 3119
# ->折射
# 3125
# ->出了
# 3131
# ->美國
# 3137
# ->價值
# 3143
# ->，比
# 3149
# ->如公
# 3155
# ->平、
# 3161
# ->正義
# 3167
# ->、民
# 3173
# ->主、
# 3179
# ->法治
# 3185
# ->、博
# 3191
# ->愛、
# 3197
# ->人權
# 3203
# ->等的
# 3209
# ->偽善
# 3215
# ->。所
# 3221
# ->有這
# 3227
# ->一切
# 3233
# ->，才
# 3239
# ->是美
# 3245
# ->國霸
# 3251
# ->權的
# 3257
# ->核心
# 3263
# ->危機
# 3269
# ->，說
# 3275
# ->到底
# 3281
# ->，這
# 3287
# ->又都
# 3293
# ->與文
# 3299
# ->化有
# 3305
# ->關。
# 3311
# ->歷史
# 3317
# ->學家
# 3323
# ->湯恩
# 3329
# ->比在
# 3335
# ->上世
# 3341
# ->紀說
# 3347
# ->，人
# 3353
# ->類2
# 3357
# ->1世
# 3361
# ->紀的
# 3367
# ->前途
# 3373
# ->看中
# 3379
# ->國，
# 3385
# ->或許
# 3391
# ->正是
# 3397
# ->從這
# 3403
# ->個角
# 3409
# ->度深
# 3415
# ->刻觀
# 3421
# ->察的
# 3427
# ->判斷
# 3433
# ->。
#
# 3438
# ->
# （
# 3443
# ->作者
# 3449
# ->為香
# 3455
# ->港鳳
# 3461
# ->凰衛
# 3467
# ->視台
# 3473
# ->資深
# 3479
# ->評論
# 3485
# ->員）
# 3491

# %%
'''
來看一下那個「兩顆字」所組成的「詞」出現的次數最多？
'''
# print(vac.keys())
# print(vac)
# print(vac.values())

for value in {value for value in vac.values()}:
    print(value)
    print({key for key in vac.keys() if vac[key] == value})

#vac_copy = vac
# Out:
# 1
# {'', '折射', '大利', '愛、', '戰結', '攻擊', '，從', '\n觀', '之外', '或早', '獨夫', '員）', '5年', '弈的', '普遍', '（經', '領導', '球的', '了美', '存在', '選舉', '盛轉', '了維', '人為', '倖免', '身都', '個獨', '，開', '蠻橫', '束綜', '但再', '國首', '國力', '且也', '，不', '塊兩', '了各', '的必', '/2', '，而', '了人', '吸納', '年一', '礎。', '到，', '迄今', '一段', '的霸', '軍力', '也可', '形成', '偽善', '仍將', '折點', '現勝', '言論', '化了', '，將', '有關', '恐戰', '港鳳', '紀之', '、博', '齊平', '治亂', '此為', '以被', '至連', '成一', ':2', '雙方', '壟斷', '些，', '獨立', '顯示', '國開', '漂亮', '最自', '止一', '\n（', '。川', '紀說', '大智', '經濟', '國最', '歷史', '心危', '許這', '到底', '實。', '量與', '輯。', '時間', '個政', '09', '個方', '在在', '踐踏', '看中', '個巨', '負結', '度深', '之後', '存續', '化約', '到2', '值不', '不意', '造成', '19', '睨全', '益集', '衰轉', '，並', '，所', '如今', '等的', '）為', '的毀', '源。', '大博', '6 ', '視台', '（含', '進入', '最終', '上世', '現了', '才前', '事務', '化成', '已然', '小聰', '，比', '而衰', '94', '的核', '義到', '的司', '作者', '不了', '的是', '與結', '評論', '權由', '受質', '制與', '報…', '機。', '21', '、國', '技、', '私，', '了全', '有著', '弈是', '行其', '人以', '與價', '貨幣', '往美', '比在', '而且', '巨大', '、華', '、情', '然邏', '設計', '果，', '義上', '，貧', '紀金', '號歷', '球人', '憑恃', '，但', '，說', '權從', '普作', '化有', '一切', '現象', '二、', '的頭', '總統', '後的', '的能', '，再', '貢獻', '持霸', '權地', '，贏', '立與', '有效', '還極', '自身', '強博', '過英', '這都', '範圍', '烈競', '非的', '之，', '國自', '應該', '從這', '實力', '在被', '，充', '運勢', '個別', '許跟', '不存', '等）', '平、', '論其', '為香', '擇手', '如下', '物尤', '會出', '事的', '面展', '詡的', '的監', '誤區', '治體', '0年', '爭與', '展，', '活力', '察美', '人權', '等也', '時看', '形象', '，人', '前途', '標竿', '代議', '步強', '川普', '綜合', '輪替', '程與', '的反', '史事', '、軍', '中美', '資深', '開始', '這一', '結果', '（2', '國際', '僅讓', '肆意', '或許', '凰衛', '正義', '類2', '了；', '竟不', '疑，', '個角', '夠容', '到1', '，實', '步的', '贏得', '已淪', '與發', '響力', '及地', '地對', '、科', '面超', '交易', '果關', '的中', '國睥', '發展', '又都', '開激', '很多', '0/', '而，', '前所', '明無', '\n然', '、過', '屈一', '盛極', '團的', '主、', '順序', '立主', '衝撞', '。所', '了極', '，無', '距、', '中方', '關。', '轉折', '各種', '是一', '值正', '還可', '略板', '重要', '與文', '制度', '場世', '並因', '制怎', '位居', '影響', '原本', '，或', '察的', '不斷', '滅性', '得國', '學家', '法治', '力全', '麼能', '參與', '美方', '本身', '能成', '件，', '出了', '美兩', '進一', '人類', '所欲', '、民', '12', '的孤', '—美', '指的', '的只', '、工', '地位', '，有', '二戰', '夢」', '爾街', '端自', '融海', '權基', '段、', '早，', '：一', '個意', '對美', '也異', '遲或', '平》', '展進', '力，', '；三', '，中', '換言', '際影', '後，', '督與', '地釋', '國家', '，才', '中巨', '治人', '惡鬥', '至美', '但必', '問是', '未見', '制衡', '正是', '肯定', '因此', '此以', '濟、', '於一', '是事', '其實', '刻觀', '作為', '湯恩', '對國', '放出', '富差', '，成', '果。', '為自', '霸業', '重，', '麼一', ' 石', '展開', '慧，', '此一', '法獨', '的因', '機\n', '嘯；', '始，', '係或', '事、', '逃避', '為政', '矛盾', '行事', '緣戰', '不顧', '而已', '強大', '竟也', '客，', '在危', '始下', '，畢', '的遲', '破壞', '國體', '類發', '第二', '為一', '業、', '實與', '個世', '為不', '軍事', '目前', '國為', '種「', '如公', '在這', '位，', '須同', '與尊', '切或', '國在', '正在', '未受', '判斷', '其是', '爭，', '種族', '的行', '值。', '傷害', '殘。', '），', '完成', '利益', '行；', '自豪', '後盾', '的綜'}
# 2
# {'核心', '02', '1世', '如果', '任何', '，甚', '、美', '18', '危機', '，意', '世紀', '壯大', '落敗', '一個', '有這', '，這', '是美', '為，', '際社', '出現', '國價', '強國', '並不', '價值', '兩黨', '的政', '過程', '會的', '合國', '以美', '能讓', '與美', '全球', '資源', '紀的'}
# 3
# {'權的', '政治', '金融', '大的', '。\n', '味著', '國，'}
# 4
# {'霸權', '\n\n', '國的', '體制'}
# 5
# {'國霸', '，美'}
# 17
# {'美國'}

# %%
test_str1 = 'GeeksforGeeks'
test_str2 = 'Codefreaks'
  
# using set() + intersection() to 
# get string intersection 
res = set(test_str1).intersection(test_str2) 
          
# printing intersection 
print ("String intersection is : " + str(res))
# Out:
# String intersection is : {'f', 'o', 'r', 's', 'k', 'e'}

# %%
'''
上面，出現部份的 key 裏，會內含帶一些標點符號的 key。
想刪掉這種 key。
要想辦法，將含這些奇怪符號的 key 給刪掉。

以下找一個比較簡潔的作法。
從網路上找到這一個例子：
'''

test_str1 = '。\n'
test_str2 = '\n；—、。， ）（'   #以這個來包含我們先瀘掉的 特別符號
  
# using set() + intersection() to 
# get string intersection 
res = set(test_str1).intersection(test_str2) 
          
# printing intersection 
print ("String intersection is : " + str(res))
type(set({}))
res == set({})
# Out:
# String intersection is : {'。', '\n'}
# False

# %%
'''
試寫一下我的狀況
注意這個 vac 只有一份，
如果 delete 之後，要記得重路再補一次
'''
to_be_deleted = '\n:/》…；—、。， ）（'  # 這些就是我一個一個去看，然後找到的
key_to_be_deleted = []
for key in vac.keys():
    #key_str = str(key)
    res = set(key).intersection(to_be_deleted)
    if res != set({}):
        key_to_be_deleted.append(key)

print("原本 vac 的 key 有： " + str(len(vac)) + "個。")
print("發現有含特殊符號的有： " + str(len(key_to_be_deleted)) + "個")
print(key_to_be_deleted)

#vac.pop(key)
# Out:
# 原本 vac 的 key 有： 511個。
# 發現有含特殊符號的有： 103個
# ['平》', '機\n', ':2', '0/', '/2', '6 ', ' 石', '\n\n', '件，', '（含', '、工', '業、', '、科', '技、', '、國', '等）', '，或', '早，', '，將', '果。', '，意', '，開', '行；', '，但', '機。', '之，', '，美', '，中', '果，', '。\n', '\n觀', '始，', '（2', '）為', '，從', '，再', '，贏', '重，', '值。', '，而', '，成', '，並', '國，', '礎。', '展，', '、美', '，充', '了；', '二、', '力，', '，實', '；三', '（經', '濟、', '、軍', '事、', '、情', '報…', '），', '\n然', '而，', '，畢', '輯。', '後，', '爭，', '嘯；', '位，', '段、', '，所', '些，', '—美', '殘。', '為，', '，這', '。川', '客，', '，有', '慧，', '私，', '實。', '到，', '，甚', '，無', '、過', '，不', '疑，', '源。', '，貧', '距、', '、華', '，比', '平、', '、民', '主、', '、博', '愛、', '。所', '，才', '，說', '關。', '，人', '\n（', '員）']

# %%
'''
我接著用較簡潔的方法 (comprehension) 寫：
但竟然發現 key_to_be_deleted = []
'''
to_be_deleted = '\n:/》…；—、。， ）（'
key_to_be_deleted = [key for key in vac if set(key).intersection(to_be_deleted) != set({})]

print(len(key_to_be_deleted))
print(key_to_be_deleted)
# Out:
# 103
# ['平》', '機\n', ':2', '0/', '/2', '6 ', ' 石', '\n\n', '件，', '（含', '、工', '業、', '、科', '技、', '、國', '等）', '，或', '早，', '，將', '果。', '，意', '，開', '行；', '，但', '機。', '之，', '，美', '，中', '果，', '。\n', '\n觀', '始，', '（2', '）為', '，從', '，再', '，贏', '重，', '值。', '，而', '，成', '，並', '國，', '礎。', '展，', '、美', '，充', '了；', '二、', '力，', '，實', '；三', '（經', '濟、', '、軍', '事、', '、情', '報…', '），', '\n然', '而，', '，畢', '輯。', '後，', '爭，', '嘯；', '位，', '段、', '，所', '些，', '—美', '殘。', '為，', '，這', '。川', '客，', '，有', '慧，', '私，', '實。', '到，', '，甚', '，無', '、過', '，不', '疑，', '源。', '，貧', '距、', '、華', '，比', '平、', '、民', '主、', '、博', '愛、', '。所', '，才', '，說', '關。', '，人', '\n（', '員）']

# %%
'''
接下來，再將這些 key_to_be_deleted 砍掉。
'''
for key in key_to_be_deleted:
    vac.pop(key)

print("剩下 vac 的 key 有： " + str(len(vac)) + "個。")
# Out:
# 剩下 vac 的 key 有： 408個。

# %%
# %whos
# Out:
# Variable            Type             Data/Info
# ----------------------------------------------
# f                   TextIOWrapper    <_io.TextIOWrapper name='<...>ode='r' encoding='utf-8'>
# f_content           str
# f_contents          str              1) This is a test file\n2<...>inth line\n10) Tenth line
# f_whole             str              石齊平》美國霸權的核心危機\n18:212020/<...>的判斷。\n\n（作者為香港鳳凰衛視台資深評論員）
# key                 str              員）
# key_to_be_deleted   list             n=103
# os                  module           <module 'os' from 'C:\\Us<...>\\Anaconda3\\lib\\os.py'>
# path_name           str              D:\Google雲端硬碟\GettingStar<...>Pi-book_release\Chapter03
# read_count          int              2
# res                 set              set()
# test_str1           str              。\n
# test_str2           str              \n；—、。， ）（
# to_be_deleted       str              \n:/》…；—、。， ）（
# vac                 dict             n=408
# value               int              17

# %% [markdown]
# ## Python 中拼音庫 PyPinyin 的用法！這個庫有點意思哈
#
# 原文網址：https://kknews.cc/code/klmpzxr.html

# %% [markdown]
# ## Installing Python Packages from a Jupyter Notebook
# https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/

# %%
# 從 jupyter notebook 安裝 pypingyin 套件`
# !pip install pypinyin
# Out:
# Requirement already satisfied: pypinyin in c:\users\public\anaconda3\lib\site-packages (0.39.0)

# %%
from pypinyin import pinyin

# %%
print(pinyin('中心'))
# Out:
# [['zhōng'], ['xīn']]

# %%
a = pinyin('中心')

# %%
type(a)
# Out:
# list

# %%
a
# Out:
# [['zhōng'], ['xīn']]

# %%
print(len(vac))
# Out:
# 408

# %%
pinyin_list_vac = [pinyin(key) for key in vac]

# %%
len(pinyin_list_vac)
# Out:
# 408

# %%
len(set(pinyin_list_vac))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-7e8e8c311068> in <module>
# ----> 1 len(set(pinyin_list_vac))
#
# TypeError: unhashable type: 'list'

# %%
'''
{中文:拼音}
'''
dict_key_py = {key: str(pinyin(key)) for key in vac.keys()}

# %%
# dict_py
len(dict_key_py)
# Out:
# 408

# %%
len(dict_key_py.values())
# Out:
# 408

# %%
len(set(dict_key_py.values()))
# Out:
# 406

# %%
'''
怎麼找得到同音詞？
'''
homophone_dict = {}
for key, value in dict_key_py.items():
    if value in homophone_dict.keys():
        print(value, homophone_dict[value])
        print(value, [key])
        homophone_dict[value].append(key)
        print(value, homophone_dict[value])
    else:
        homophone_dict[value] = [key]

#print(len(homophone_dict))
# Out:
# [['de'], ['shì']] ['的是']
# [['de'], ['shì']] ['地釋']
# [['de'], ['shì']] ['的是', '地釋']
# [['quán'], ['de']] ['權的']
# [['quán'], ['de']] ['權地']
# [['quán'], ['de']] ['權的', '權地']

# %%
new_dict = {}
for key, value in vac.items():
    if str(pinyin(key)) in new_dict.keys():
        print(key + str(pinyin(key)))
        new_dict[str(pinyin(key))] += 1
    else:
        new_dict[str(pinyin(key))] = 1

print(len(new_dict))
# Out:
# 地釋[['de'], ['shì']]
# 權地[['quán'], ['de']]
# 406

# %%
# %lsmagic

# %%
#id(vac) == id(vac_copy)

# %% [markdown]
# ## 我遇到一個狀況：下面我要將內含標點符號的 key 給刪掉，但是在展示兩種寫法 (list comprehension 以及對等的 for loop時，發現，要是前一個被刪掉後，後面那個就看不到了。然後，我想跟脆也準備一份 copy，結果，竟然是指向相同的 dictionay 的物件，所以用不上。如果真的要解決，就得強迫另外再作一個 dictionary。
